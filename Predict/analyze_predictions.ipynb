# %%
import pandas as pd
from predict import make_predictions

predictions_df = make_predictions('2016-06-01', '2026-06-01')

predictions_df.head()

predictions_df.to_csv('predictions_df.csv', index=False)

# %%
print(predictions_df.predicted_count.describe())
predictions_df.hist('predicted_count', bins=40)

# %%
import matplotlib.pyplot as plt

plt.plot(predictions_df['yday'], predictions_df['predicted_count'])
# plt.xlim(300, 345)
